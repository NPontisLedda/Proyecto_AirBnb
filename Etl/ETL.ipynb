# %% [markdown]
# <a href="https://colab.research.google.com/github/NPontisLedda/Proyecto_AirBnb/blob/main/Etl/ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ETL de datos de AirBnb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importamos las librerías necesarias

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Comenzamos a trabajar con cada dataset por separado

# %% [markdown]
# ### Dataset de *Calendar*

# %%
# Comenzamos a trabajar con los datasets por separado

df_calendar = pd.read_csv('/content/drive/MyDrive/Proyectos/Proyecto_AirBnb/Datasets/calendar.csv')

df_calendar.head(3)
# Out:
#    listing_id        date available      price adjusted_price  minimum_nights  \
# 0       50778  2020-04-26         f  $2,655.00      $2,655.00             5.0
# 1      133654  2020-04-27         t  $1,150.00      $1,150.00             4.0
# 2      133654  2020-04-28         t  $1,150.00      $1,150.00             4.0
#
#    maximum_nights
# 0          1125.0
# 1          1125.0
# 2          1125.0

# %%
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8661181 entries, 0 to 8661285
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   price           object
#  3   adjusted_price  object
#  4   minimum_nights  float64
#  5   maximum_nights  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 462.6+ MB

# %%
df_calendar.shape
# Out:
# (8661286, 7)

# %%
df_calendar = df_calendar.dropna()

# %%
df_calendar.shape
# Out:
# (8661181, 7)

# %% [markdown]
# ###### Eliminamos la columna available ya que no resulta útil y no se entiende la info que contiene.

# %%
df_calendar = df_calendar.drop(columns=['available'])

# %%
df_calendar
# Out:
#          listing_id        date      price adjusted_price  minimum_nights  \
# 0             50778  2020-04-26  $2,655.00      $2,655.00             5.0
# 1            133654  2020-04-27  $1,150.00      $1,150.00             4.0
# 2            133654  2020-04-28  $1,150.00      $1,150.00             4.0
# 3            133654  2020-04-29  $1,150.00      $1,150.00             4.0
# 4            133654  2020-04-30  $1,150.00      $1,150.00             4.0
# ...             ...         ...        ...            ...             ...
# 8661281    43178560  2021-04-21  $3,319.00      $3,319.00             1.0
# 8661282    43178560  2021-04-22  $3,319.00      $3,319.00             1.0
# 8661283    43178560  2021-04-23  $3,319.00      $3,319.00             1.0
# 8661284    43178560  2021-04-24  $3,319.00      $3,319.00             1.0
# 8661285    43178560  2021-04-25  $3,319.00      $3,319.00             1.0
#
#          maximum_nights
# 0                1125.0
# 1                1125.0
# ...

# %% [markdown]
# Modificamos los posibles datos nulos que hayan quedado por 'Sin Dato', para evitar futuros errores.

# %%
df_calendar.fillna('Sin Dato', inplace= True)

# %% [markdown]
# ###### Exportamos los datos a un archivo csv

# %%
df_calendar.to_csv('calendar_limpio.csv', index= False)

# %% [markdown]
# ### Dataset de listings, el mismo contiene el detalle de cada operación (inclueye datos descriptivo de la vivienda)

# %%
df_listings = pd.read_csv('/content/drive/MyDrive/Proyectos/Proyecto_AirBnb/Datasets/listings.csv')
# Out:
# <ipython-input-10-68b42adde350>:1: DtypeWarning: Columns (61,62,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_listings = pd.read_csv('/content/drive/MyDrive/Proyectos/Proyecto_AirBnb/Datasets/listings.csv')

# %% [markdown]
# ###### Procedemos a eliminar columnas que no son necesarias para el análisis.

# %%
df_listings = df_listings.drop(columns=['experiences_offered', 'has_availability', 'cancellation_policy', 'calendar_updated', 'summary', 'transit',
                                        'access', 'interaction', 'neighbourhood_cleansed',
                                        'neighbourhood_group_cleansed', 'market', 'country_code', 'room_type'])

# %%
df_listings = df_listings.drop(columns=['security_deposit', 'is_location_exact', 'smart_location'])

# %%
df_listings = df_listings.drop(columns=['requires_license', 'license',
       'jurisdiction_names', 'instant_bookable', 'is_business_travel_ready','require_guest_profile_picture',
       'require_guest_phone_verification'])

# %%
df_listings = df_listings.drop(columns=[
       'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
       'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
       'host_about', 'host_response_time', 'host_response_rate',
       'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
       'host_picture_url', 'host_neighbourhood', 'host_listings_count',
       'host_total_listings_count', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified', 'minimum_minimum_nights', 'maximum_minimum_nights',
       'minimum_maximum_nights', 'maximum_maximum_nights',
       'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_30', 'availability_60',
       'availability_90', 'availability_365', 'calendar_last_scraped', 'first_review', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication'])

# %%
df_listings = df_listings.drop(columns=['cleaning_fee', 'guests_included', 'extra_people', 'beds', 'bed_type',
                                        'house_rules', 'listing_url', 'scrape_id', 'last_scraped', 'number_of_reviews_ltm',
                                        ])

# %%
df_listings = df_listings.drop(columns=['number_of_reviews', 'last_review', 'review_scores_rating',
       'review_scores_location', 'review_scores_value',
       'calculated_host_listings_count',
       'calculated_host_listings_count_entire_homes',
       'calculated_host_listings_count_private_rooms',
       'calculated_host_listings_count_shared_rooms', 'reviews_per_month'])

# %%
df_listings = df_listings.drop(columns=['zipcode', 'minimum_nights', 'maximum_nights'])

# %%
df_listings = df_listings.drop(columns=['accommodates', 'bathrooms', 'bedrooms', 'square_feet', 'weekly_price', 'monthly_price'])

# %%
df_listings = df_listings.drop(columns=['notes'])

# %%
df_listings.columns
# Out:
# Index(['id', 'name', 'space', 'description', 'neighborhood_overview', 'street',
#        'neighbourhood', 'city', 'state', 'country', 'latitude', 'longitude',
#        'property_type', 'amenities', 'price'],
#       dtype='object')

# %%
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23729 entries, 0 to 23728
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     23729 non-null  int64
#  1   name                   23719 non-null  object
#  2   space                  16535 non-null  object
#  3   description            22928 non-null  object
#  4   neighborhood_overview  16064 non-null  object
#  5   street                 23729 non-null  object
#  6   neighbourhood          23729 non-null  object
#  7   city                   23142 non-null  object
#  8   state                  23546 non-null  object
#  9   country                23729 non-null  object
#  10  latitude               23729 non-null  float64
#  11  longitude              23729 non-null  float64
#  12  property_type          23729 non-null  object
#  13  amenities              23729 non-null  object
# ...

# %%
df_listings.head(3)
# Out:
#       id                                 name  \
# 0  11508   Amazing Luxurious Apt-Palermo Soho
# 1  12463  Room in Recoleta - awesome location
# 2  13095   Standard Room at Palermo Viejo B&B
#
#                                                space  \
# 0  LUXURIOUS NEW APT: 1 BDRM- POOL/ GYM/ SPA/ 24-...
# 1  This is a very comfortable pull-out sofa in th...
# 2  Standard room : Palermo Viejo Bed & Breakfast ...
#
#                                          description  \
# 0  LUXURIOUS NEW APT: 1 BDRM- POOL/ GYM/ SPA/ 24-...
# 1  My apartment is centrally located in Recoleta ...
# 2  Palermo Viejo B&B is a typical home in one of ...
#
#                                neighborhood_overview  \
# 0  AREA: PALERMO SOHO Minutes walking distance fr...
# 1  It's near the school of medicine so the street...
# 2                                                NaN
#
#                                      street neighbourhood          city  \
# ...

# %% [markdown]
# Reemplazamos todos los datos nulos por 'Sin Dato', para no tener errores luego.

# %%
df_listings.fillna('Sin Dato', inplace= True)

# %% [markdown]
# Exportamos los datos a un csv

# %%
df_listings.to_csv('listings_limpio.csv', index= False)

# %% [markdown]
# ### Dataset de reviews

# %%
df_reviews = pd.read_csv('/content/drive/MyDrive/Proyectos/Proyecto_AirBnb/Datasets/reviews.csv')

# %%
df_reviews.head(3)
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0       11508  1615861  2012-07-02       877808       Charlie
# 1       11508  3157005  2012-12-26       656077        Shaily
# 2       11508  3281011  2013-01-05      2835998       Michiel
#
#                                             comments
# 0  Amazing place!\r\n\r\nLocation: short walk to ...
# 1  Really enjoyed Candela's recommendations and q...
# 2  Candela and her colleague were very attentive ...

# %%
df_reviews = df_reviews.drop(columns= 'reviewer_name')

# %%
df_reviews.dropna(inplace= True)

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 386928 entries, 0 to 387098
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   listing_id   386928 non-null  int64
#  1   id           386928 non-null  int64
#  2   date         386928 non-null  object
#  3   reviewer_id  386928 non-null  int64
#  4   comments     386928 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 17.7+ MB

# %%
df_reviews.head()
# Out:
#    listing_id       id        date  reviewer_id  \
# 0       11508  1615861  2012-07-02       877808
# 1       11508  3157005  2012-12-26       656077
# 2       11508  3281011  2013-01-05      2835998
# 3       11508  6050019  2013-07-28      4600436
# 4       11508  9328455  2013-12-22      3130017
#
#                                             comments
# 0  Amazing place!\r\n\r\nLocation: short walk to ...
# 1  Really enjoyed Candela's recommendations and q...
# 2  Candela and her colleague were very attentive ...
# 3  The apartment was in a beautiful, modern build...
# 4  My stay at Candela's apartment was very enjoya...

# %% [markdown]
# # Hacer analisis de sentimiento de los comentarios de arriba

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
# Descargamos los recursos necesarios para NLTK (solo es necesario la primera vez)
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
#Se crea el analizador de sentimientos

sia= SentimentIntensityAnalyzer()

#Función para aplicar el análisis de sentimiento

def analyze_sentiment_or_default(text):
    if isinstance(text,str):
        compound_score = sia.polarity_scores(text)['compound']
        if compound_score >= 0.05:
            return 2
        elif compound_score <= -0.05:
            return 0
        else:
            return 1
    else:
        return 1

#Aplicamos el análisis sobre la columna 'comments' y creamos la columna 'sentiment_analysis', que va a reemplazar a la columna comments.

df_reviews['sentiment_analysis']= df_reviews['comments'].apply(analyze_sentiment_or_default)
df_reviews.drop(columns=['comments'], inplace=True)

# %%
df_reviews.head(3)
# Out:
#    listing_id       id        date  reviewer_id  sentiment_analysis
# 0       11508  1615861  2012-07-02       877808                   2
# 1       11508  3157005  2012-12-26       656077                   2
# 2       11508  3281011  2013-01-05      2835998                   2

# %%
# Extraemos los datos a un csv

df_reviews.to_csv('reviews_limpios.csv', index= False)

# %% [markdown]
# Si los archivos no pueden ser descargados simplemente desde la opción 'Descargar' en los tres puntitos de cada uno de los archivos, utilizamos las siguientes líneas de código.

# %%
from google.colab import files

# %%
files.download ('/content/listings_limpio.csv')

# %%
files.download ('/content/calendar_limpio.csv')
